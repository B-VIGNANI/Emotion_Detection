# %%
import os
import glob
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.layers import TimeDistributed 
import tkinter as tk
from tkinter import filedialog
from pydub import AudioSegment
import sounddevice as sd
from PIL import Image, ImageTk
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
import os
import glob
import librosa
import numpy as np

# Feature extraction function
def extract_features(file_path):
    audio, sr = librosa.load(file_path, res_type='kaiser_fast')
    features = np.mean(librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13).T, axis=0)
    return features

# Updated dataset path
dataset_path = r"C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data"

data = []
labels = []

# Loop through folders and process .wav files
for folder_name in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder_name)
    for file_path in glob.glob(os.path.join(folder_path, '*.wav')):
        print(file_path)
        features = extract_features(file_path)
        data.append(features)
        labels.append(folder_name)
# Out:
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_back_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bar_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_base_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bath_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bean_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_beg_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bite_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_boat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bone_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_book_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_bought_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_burn_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_cab_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_calm_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_came_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_cause_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_chain_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_chair_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_chalk_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_chat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_check_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_cheek_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_chief_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_choice_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_cool_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dab_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_date_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dead_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_death_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_deep_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dime_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dip_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_ditch_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dodge_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_dog_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_doll_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_door_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_fail_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_fall_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_far_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_fat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_fit_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_five_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_food_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_gap_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_gas_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_gaze_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_germ_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_get_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_gin_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_goal_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_good_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_goose_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_gun_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_half_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hall_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hash_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hate_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_have_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_haze_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hire_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hit_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hole_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_home_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hurl_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_hush_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_jail_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_jar_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_join_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_judge_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_jug_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_juice_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_keen_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_keep_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_keg_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_kick_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_kill_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_king_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_kite_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_knock_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_late_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_laud_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lean_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_learn_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lease_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lid_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_life_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_limb_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_live_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_loaf_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_long_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lore_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lose_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_lot_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_love_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_luck_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_make_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_match_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_merge_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mess_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_met_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mill_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mob_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mode_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mood_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_moon_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mop_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_mouse_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_nag_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_name_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_near_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_neat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_nice_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_note_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_numb_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pad_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_page_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pain_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pass_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pearl_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_peg_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_perch_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_phone_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pick_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pike_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pole_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_pool_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_puff_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rag_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_raid_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rain_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_raise_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_reach_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_read_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_red_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_ring_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_ripe_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_road_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_room_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rose_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rot_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rough_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_rush_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_said_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sail_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_search_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_seize_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sell_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_shack_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_shall_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_shawl_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sheep_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_shirt_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_should_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_shout_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_size_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_soap_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_soup_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sour_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_south_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sub_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_such_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_sure_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_take_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_talk_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tape_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_team_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tell_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_thin_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_third_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_thought_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_thumb_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_time_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tip_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tire_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_ton_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tool_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_tough_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_turn_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_vine_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_voice_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_void_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_vote_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_wag_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_walk_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_wash_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_week_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_wheat_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_when_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_which_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_whip_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_white_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_wife_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_wire_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_witch_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_yearn_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_yes_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_young_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_angry\OAF_youth_angry.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_back_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bar_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_base_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bath_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bean_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_beg_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bite_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_boat_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bone_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_book_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_bought_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_burn_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_cab_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_calm_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_came_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_cause_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_chain_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_chair_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_chalk_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_chat_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_check_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_cheek_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_chief_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_choice_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_cool_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dab_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_date_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dead_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_death_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_deep_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dime_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dip_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_ditch_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dodge_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_dog_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_doll_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_door_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_fail_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_fall_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_far_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_fat_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_fit_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_five_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_food_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_gap_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_gas_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_gaze_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_germ_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_get_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_gin_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_goal_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_good_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_goose_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_gun_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_half_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hall_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hash_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hate_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_have_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_haze_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hire_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hit_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hole_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_home_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hurl_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_hush_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_jail_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_jar_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_join_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_judge_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_jug_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_juice_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_keen_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_keep_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_keg_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_kick_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_kill_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_king_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_kite_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_knock_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_late_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_laud_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lean_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_learn_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lease_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lid_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_life_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_limb_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_live_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_loaf_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_long_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lore_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lose_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_lot_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_love_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_luck_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_make_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_match_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_merge_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mess_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_met_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mill_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mob_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mode_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mood_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_moon_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mop_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_mouse_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_nag_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_name_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_near_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_neat_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_nice_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_note_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_numb_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_pad_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_page_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_pain_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_pass_disgust.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\OAF_disgust\OAF_pearl_disgust.wav
# ...
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_long_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_lore_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_lose_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_lot_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_love_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_luck_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_make_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_match_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_merge_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mess_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_met_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mill_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mob_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mode_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mood_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_moon_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mop_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_mouse_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_nag_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_name_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_near_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_neat_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_nice_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_note_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_numb_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pad_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_page_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pain_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pass_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pearl_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_peg_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_perch_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_phone_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pick_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pike_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pole_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_pool_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_puff_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rag_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_raid_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rain_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_raise_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rat_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_reach_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_read_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_red_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_ring_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_ripe_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_road_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_room_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rose_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rot_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rough_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_rush_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_said_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sail_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_search_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_seize_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sell_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_shack_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_shall_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_shawl_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sheep_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_shirt_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_should_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_shout_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_size_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_soap_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_soup_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sour_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_south_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sub_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_such_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_sure_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_take_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_talk_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tape_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_team_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tell_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_thin_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_third_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_thought_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_thumb_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_time_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tip_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tire_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_ton_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tool_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_tough_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_turn_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_vine_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_voice_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_void_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_vote_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_wag_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_walk_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_wash_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_week_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_wheat_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_when_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_which_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_whip_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_white_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_wife_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_wire_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_witch_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_yearn_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_yes_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_young_sad.wav
# C:\Users\moham\Downloads\Emotion_Recognition_Project\Speech_Emotion_Recognition\TESS Toronto emotional speech set data\YAF_sad\YAF_youth_sad.wav

# %%
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
X_train, X_test, y_train, y_test = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

X_train = np.array(X_train)[:, np.newaxis, :]
X_test = np.array(X_test)[:, np.newaxis, :]

model = Sequential()
model.add(TimeDistributed(Dense(256, activation='relu'), input_shape=(1, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(128))
model.add(Dropout(0.5))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

loss, accuracy = model.evaluate(X_test, y_test)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# c:\Users\moham\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.0725 - loss: 2.8384 - val_accuracy: 0.0661 - val_loss: 2.6496
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0686 - loss: 2.7461 - val_accuracy: 0.1339 - val_loss: 2.5943
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0755 - loss: 2.6960 - val_accuracy: 0.1339 - val_loss: 2.6030
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0765 - loss: 2.6506 - val_accuracy: 0.0893 - val_loss: 2.5590
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1087 - loss: 2.5909 - val_accuracy: 0.1786 - val_loss: 2.4719
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1259 - loss: 2.5289 - val_accuracy: 0.3304 - val_loss: 2.2745
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1587 - loss: 2.4511 - val_accuracy: 0.1875 - val_loss: 2.1893
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1822 - loss: 2.2945 - val_accuracy: 0.2464 - val_loss: 2.0322
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2062 - loss: 2.1747 - val_accuracy: 0.3036 - val_loss: 1.9012
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2665 - loss: 2.0296 - val_accuracy: 0.3554 - val_loss: 1.8138
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2753 - loss: 1.9445 - val_accuracy: 0.4393 - val_loss: 1.6802
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3366 - loss: 1.8136 - val_accuracy: 0.5821 - val_loss: 1.4819
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3773 - loss: 1.6652 - val_accuracy: 0.5982 - val_loss: 1.3741
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4235 - loss: 1.5494 - val_accuracy: 0.6482 - val_loss: 1.2488
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4750 - loss: 1.4433 - val_accuracy: 0.5946 - val_loss: 1.1935
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5151 - loss: 1.3409 - val_accuracy: 0.6750 - val_loss: 1.0693
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5160 - loss: 1.2892 - val_accuracy: 0.7089 - val_loss: 0.9605
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5459 - loss: 1.2029 - val_accuracy: 0.7518 - val_loss: 0.8747
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5754 - loss: 1.1170 - val_accuracy: 0.8000 - val_loss: 0.7629
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6452 - loss: 1.0004 - val_accuracy: 0.8179 - val_loss: 0.6801
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6525 - loss: 0.9406 - val_accuracy: 0.8304 - val_loss: 0.6080
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6799 - loss: 0.8797 - val_accuracy: 0.8446 - val_loss: 0.5443
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7086 - loss: 0.7937 - val_accuracy: 0.8661 - val_loss: 0.4998
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7316 - loss: 0.7480 - val_accuracy: 0.8875 - val_loss: 0.4366
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7654 - loss: 0.6754 - val_accuracy: 0.8875 - val_loss: 0.4086
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7813 - loss: 0.6514 - val_accuracy: 0.8946 - val_loss: 0.3765
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7745 - loss: 0.6486 - val_accuracy: 0.8893 - val_loss: 0.3540
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8232 - loss: 0.5464 - val_accuracy: 0.9071 - val_loss: 0.3382
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8056 - loss: 0.5718 - val_accuracy: 0.8964 - val_loss: 0.3172
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8001 - loss: 0.5688 - val_accuracy: 0.8982 - val_loss: 0.3130
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8187 - loss: 0.5365 - val_accuracy: 0.8964 - val_loss: 0.3060
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8066 - loss: 0.5233 - val_accuracy: 0.9089 - val_loss: 0.2859
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8275 - loss: 0.5187 - val_accuracy: 0.9071 - val_loss: 0.2974
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8221 - loss: 0.5208 - val_accuracy: 0.9143 - val_loss: 0.2838
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8393 - loss: 0.4587 - val_accuracy: 0.9161 - val_loss: 0.2639
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8177 - loss: 0.4920 - val_accuracy: 0.8946 - val_loss: 0.2886
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8236 - loss: 0.4918 - val_accuracy: 0.9071 - val_loss: 0.2825
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8652 - loss: 0.4142 - val_accuracy: 0.9036 - val_loss: 0.2737
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8508 - loss: 0.4077 - val_accuracy: 0.9071 - val_loss: 0.2485
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8324 - loss: 0.4370 - val_accuracy: 0.9179 - val_loss: 0.2453
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8530 - loss: 0.4210 - val_accuracy: 0.9179 - val_loss: 0.2306
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8426 - loss: 0.4127 - val_accuracy: 0.9161 - val_loss: 0.2329
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8589 - loss: 0.4000 - val_accuracy: 0.9179 - val_loss: 0.2339
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8508 - loss: 0.4220 - val_accuracy: 0.9250 - val_loss: 0.2235
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8755 - loss: 0.3797 - val_accuracy: 0.9125 - val_loss: 0.2287
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8679 - loss: 0.3825 - val_accuracy: 0.9179 - val_loss: 0.2271
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8611 - loss: 0.3716 - val_accuracy: 0.9125 - val_loss: 0.2306
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8715 - loss: 0.3593 - val_accuracy: 0.9179 - val_loss: 0.2226
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8753 - loss: 0.3616 - val_accuracy: 0.9179 - val_loss: 0.2172
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8651 - loss: 0.3659 - val_accuracy: 0.9107 - val_loss: 0.2270
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8954 - loss: 0.2423
# Test loss: 0.22696788609027863
# Test accuracy: 0.9107142686843872

# %%
def predict_emotion(audio_file):
    features = extract_features(audio_file)
    features = features[np.newaxis, np.newaxis, :]  
    print("Features shape:", features.shape)
    print("Features:", features)

    predicted_probabilities = model.predict(features)
    print("Predicted probabilities shape:", predicted_probabilities.shape)
    print("Predicted probabilities:", predicted_probabilities)

    predicted_label_index = np.argmax(predicted_probabilities)
    print("Predicted label index:", predicted_label_index)

    predicted_emotion = label_encoder.classes_[predicted_label_index]
    print("Predicted emotion:", predicted_emotion)


    # Emotion mapping for TESS dataset
    emotion_mapping = {
        'YAF_angry': 'ANGRY',
        'YAF_disgust': 'DISGUST',
        'YAF_fear': 'FEAR',
        'YAF_happy': 'HAPPY',
        'YAF_neutral': 'NEUTRAL',
        'YAF_pleasant_surprised': 'SURPRISED',
        'YAF_sad': 'SAD',
        'OAF_angry': 'ANGRY',
        'OAF_disgust': 'DISGUST',
        'OAF_Fear': 'FEAR',
        'OAF_happy': 'HAPPY',
        'OAF_neutral': 'NEUTRAL',
        'OAF_Pleasant_surprised': 'SURPRISED',
        'OAF_Sad': 'SAD',
    }


    recognizable_emotion = emotion_mapping.get(predicted_emotion)
    return recognizable_emotion

# %%
pip install sounddevice scipy matplotlib pillow
# Out:
# Requirement already satisfied: sounddevice in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (1.15.2)
# Requirement already satisfied: matplotlib in c:\users\moham\appdata\roaming\python\python312\site-packages (3.8.4)
# Requirement already satisfied: pillow in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (10.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\moham\appdata\roaming\python\python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\moham\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moham\appdata\roaming\python\python312\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\moham\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\moham\appdata\roaming\python\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
## simple interface app(without image)
import os
import csv
import tkinter as tk
from tkinter import filedialog, messagebox
from PIL import ImageTk
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np
import sounddevice as sd
import scipy.io.wavfile as wav
import tempfile

# Dummy emotion prediction function — replace with your actual model
def predict_emotion(audio_path):
    print(f"[DEBUG] Predicting emotion for: {audio_path}")
    emotions = ['HAPPY', 'SAD', 'ANGRY', 'SURPRISED', 'NEUTRAL', 'FEAR', 'DISGUST']
    probabilities = np.random.dirichlet(np.ones(len(emotions)), size=1).flatten()
    predicted_index = np.argmax(probabilities)
    print(f"[DEBUG] Predicted emotion: {emotions[predicted_index]} with probabilities: {probabilities}")
    return emotions[predicted_index], dict(zip(emotions, probabilities))

class EmotionApp:
    def __init__(self, root):
        print("[DEBUG] Initializing EmotionApp")
        self.root = root
        self.root.title("Speech Emotion Recognition")
        self.root.geometry("600x600")
        self.dark_mode = False

        self.base_emoji_path = r"C:\\Users\\moham\\Downloads\\Emotion_Recognition_Project\\Speech_Emotion_Recognition\\Emotion Emojis\\Emoji"
        self.emotion_to_emoji = {
            "HAPPY": os.path.join(self.base_emoji_path, "happy.gif"),
            "SAD": os.path.join(self.base_emoji_path, "sad.gif"),
            "ANGRY": os.path.join(self.base_emoji_path, "angry.gif"),
            "SURPRISED": os.path.join(self.base_emoji_path, "surprised.gif"),
            "NEUTRAL": os.path.join(self.base_emoji_path, "neutral.gif"),
            "FEAR": os.path.join(self.base_emoji_path, "fear.gif"),
            "DISGUST": os.path.join(self.base_emoji_path, "disgust.gif")
        }

        self.emoji_label = None
        self.emoji_image = None
        self.prediction_history = []

        self.show_home_page()

    def clear_window(self):
        print("[DEBUG] Clearing window")
        for widget in self.root.winfo_children():
            widget.destroy()

    def apply_theme(self):
        print(f"[DEBUG] Applying theme. Dark mode: {self.dark_mode}")
        bg = '#1e1e1e' if self.dark_mode else 'white'
        fg = 'white' if self.dark_mode else 'black'
        self.root.configure(bg=bg)
        return bg, fg

    def back_button(self, command):
        print("[DEBUG] Displaying back button")
        tk.Button(self.root, text="\u2190 Back", command=command, bg='lightgrey').place(x=10, y=10)

    def show_home_page(self):
        print("[DEBUG] Showing home page")
        self.clear_window()
        bg, fg = self.apply_theme()

        tk.Label(self.root, text="\U0001F3A7 Speech Emotion Recognition", font=('Helvetica bold', 18), bg=bg, fg=fg).pack(pady=40)

        tk.Button(self.root, text="\U0001F399\ufe0f Record Audio", command=self.record_audio_page, bg='orange').pack(pady=10)
        tk.Button(self.root, text="\U0001F4C1 Upload Audio", command=self.upload_audio_page, bg='lightgreen').pack(pady=10)
        tk.Button(self.root, text="\U0001F4DC Prediction History", command=self.show_history_page, bg='lightblue').pack(pady=10)
        tk.Button(self.root, text="\U0001F4D8 User Manual", command=self.show_user_manual, bg='khaki').pack(pady=10)
        tk.Button(self.root, text="\u2139\ufe0f About the App", command=self.show_about_page, bg='lavender').pack(pady=10)
        tk.Button(self.root, text="\U0001F319 Toggle Dark Mode", command=self.toggle_dark_mode, bg='gray').pack(pady=10)
        tk.Button(self.root, text="\u274C Exit", command=self.confirm_exit, bg='red', fg='white').pack(pady=10)

    def confirm_exit(self):
        print("[DEBUG] Confirming exit")
        if messagebox.askokcancel("Exit", "Do you really want to exit?"):
            self.root.destroy()

    def toggle_dark_mode(self):
        print("[DEBUG] Toggling dark mode")
        self.dark_mode = not self.dark_mode
        self.show_home_page()

    def show_user_manual(self):
        print("[DEBUG] Showing user manual")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        manual = (
            "\U0001F4D8 USER MANUAL\n\n"
            "1. \U0001F399\ufe0f Click 'Record Audio' to use your microphone.\n"
            "2. \U0001F4C1 Click 'Upload Audio' to select a .wav file.\n"
            "3. After prediction, you'll see:\n"
            "   - Emotion name\n"
            "   - Emoji animation\n"
            "   - Emotion probability chart\n"
            "4. Check 'Prediction History' for past results.\n"
            "5. Only '.wav' files are supported."
        )
        tk.Label(self.root, text=manual, justify="left", font=('Arial', 12), wraplength=550, bg=bg, fg=fg).pack(padx=20, pady=30)

    def show_about_page(self):
        print("[DEBUG] Showing about page")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        about = (
            "\u2139\ufe0f ABOUT THE APP\n\n"
            "\U0001F539 FEATURES:\n"
            "- Record or upload audio\n"
            "- Predict emotion from speech\n"
            "- Animated emoji output\n"
            "- Bar chart of prediction confidence\n"
            "- Export results as CSV\n"
            "- Dark mode UI\n\n"
            "\U0001F539 APPLICATIONS:\n"
            "- AI Assistants\n"
            "- Customer Service\n"
            "- Mental Health Monitoring\n"
            "- Learning & Research\n\n"
            "\U0001F539 CREDITS:\n"
            "- Dataset: TESS (University of Toronto)\n"
            "- Developed using Python + Tkinter"
        )
        tk.Label(self.root, text=about, justify="left", font=('Arial', 12), wraplength=550, bg=bg, fg=fg).pack(padx=20, pady=30)

    def show_history_page(self):
        print("[DEBUG] Showing prediction history")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        tk.Label(self.root, text="\U0001F4DC Prediction History", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=20)

        if self.prediction_history:
            for i, (file_name, emotion) in enumerate(self.prediction_history[::-1], start=1):
                print(f"[DEBUG] History item: {file_name}, {emotion}")
                tk.Label(self.root, text=f"{i}. {file_name} — Emotion: {emotion}", bg=bg, fg=fg).pack(anchor='w', padx=20)
            tk.Button(self.root, text="\U0001F4BE Export as CSV", command=self.export_csv, bg='orange').pack(pady=10)
        else:
            tk.Label(self.root, text="No history yet.", bg=bg, fg=fg).pack()

    def export_csv(self):
        print("[DEBUG] Exporting prediction history to CSV")
        file_path = filedialog.asksaveasfilename(defaultextension=".csv", filetypes=[("CSV files", "*.csv")])
        if file_path:
            with open(file_path, mode='w', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(["File Name", "Predicted Emotion"])
                writer.writerows(self.prediction_history)
            messagebox.showinfo("Success", "History exported successfully!")

    def upload_audio_page(self):
        print("[DEBUG] Showing upload audio page")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        def choose_file():
            print("[DEBUG] Opening file dialog")
            file_path = filedialog.askopenfilename(filetypes=[("WAV Audio", "*.wav")])
            if file_path:
                print(f"[DEBUG] File selected: {file_path}")
                self.display_result(file_path, os.path.basename(file_path))

        tk.Label(self.root, text="\U0001F4C1 Upload a WAV File", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=40)
        tk.Button(self.root, text="Upload Audio", command=choose_file, bg='orange').pack(pady=10)

    def record_audio_page(self):
        print("[DEBUG] Showing record audio page")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        def record_and_predict():
            print("[DEBUG] Starting recording")
            duration = 4
            fs = 44100
            tk.Label(self.root, text="Recording...", fg="red", bg=bg).pack()
            recording = sd.rec(int(duration * fs), samplerate=fs, channels=1)
            sd.wait()

            with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_file:
                wav.write(temp_file.name, fs, recording)
                print(f"[DEBUG] Recorded audio saved to: {temp_file.name}")
                self.display_result(temp_file.name, "Recorded_Audio.wav")

        tk.Label(self.root, text="\U0001F399\ufe0f Record Your Voice", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=40)
        tk.Button(self.root, text="Start Recording", command=record_and_predict, bg='orange').pack(pady=10)

    def display_result(self, file_path, file_name):
        print(f"[DEBUG] Displaying result for: {file_name}")
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()

        predicted_emotion, probabilities = predict_emotion(file_path)
        self.prediction_history.append((file_name, predicted_emotion))

        tk.Label(self.root, text="Predicted Emotion:", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=10)
        tk.Label(self.root, text=predicted_emotion, font=('Helvetica bold', 20), fg='blue', bg=bg).pack()

        emoji_path = self.emotion_to_emoji.get(predicted_emotion)
        if emoji_path and os.path.exists(emoji_path):
            print(f"[DEBUG] Loading emoji from: {emoji_path}")
            self.emoji_image = tk.PhotoImage(file=emoji_path)
            resized = self.emoji_image.subsample(int(self.emoji_image.width() / 240))
            self.emoji_label = tk.Label(self.root, image=resized, bg=bg)
            self.emoji_label.image = resized
            self.emoji_label.pack(pady=10)

        self.show_emotion_bar_chart(probabilities)

    def show_emotion_bar_chart(self, probabilities):
        print("[DEBUG] Displaying emotion bar chart")
        fig, ax = plt.subplots(figsize=(6, 3), dpi=100)
        emotions = list(probabilities.keys())
        probs = list(probabilities.values())

        ax.bar(emotions, probs, color='skyblue')
        ax.set_title('Emotion Probabilities')
        ax.set_ylim(0, 1)
        ax.set_ylabel('Probability')

        canvas = FigureCanvasTkAgg(fig, master=self.root)
        canvas.draw()
        canvas.get_tk_widget().pack(pady=10)

if __name__ == "__main__":
    print("[DEBUG] Starting EmotionApp GUI")
    root = tk.Tk()
    app = EmotionApp(root)
    root.mainloop()
# Out:
# [DEBUG] Starting EmotionApp GUI
# [DEBUG] Initializing EmotionApp
# [DEBUG] Showing home page
# [DEBUG] Clearing window
# [DEBUG] Applying theme. Dark mode: False

# %%
## speeh emotion recognition app (final)
import os
import csv
import tkinter as tk
from tkinter import filedialog, messagebox
from PIL import ImageTk, Image
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np
import sounddevice as sd
import scipy.io.wavfile as wav
import tempfile

# Dummy emotion prediction function — replace with your actual model
def predict_emotion(audio_path):
    emotions = ['HAPPY', 'SAD', 'ANGRY', 'SURPRISED', 'NEUTRAL', 'FEAR', 'DISGUST']
    probabilities = np.random.dirichlet(np.ones(len(emotions)), size=1).flatten()
    predicted_index = np.argmax(probabilities)
    return emotions[predicted_index], dict(zip(emotions, probabilities))

class EmotionApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech Emotion Recognition")
        self.root.geometry("1000x600")
        self.dark_mode = False

        self.base_emoji_path = r"C:\\Users\\moham\\Downloads\\Emotion_Recognition_Project\\Speech_Emotion_Recognition\\Emotion Emojis\\Emoji"
        self.logo_path = r"C:\\Users\\moham\\Downloads\\Emotion_Recognition_Project\\Speech_Emotion_Recognition\\images\\logo.png"
        self.emotion_to_emoji = {
            "HAPPY": os.path.join(self.base_emoji_path, "happy.gif"),
            "SAD": os.path.join(self.base_emoji_path, "sad.gif"),
            "ANGRY": os.path.join(self.base_emoji_path, "angry.gif"),
            "SURPRISED": os.path.join(self.base_emoji_path, "surprised.gif"),
            "NEUTRAL": os.path.join(self.base_emoji_path, "neutral.gif"),
            "FEAR": os.path.join(self.base_emoji_path, "fear.gif"),
            "DISGUST": os.path.join(self.base_emoji_path, "disgust.gif")
        }

        self.emoji_label = None
        self.emoji_image = None
        self.prediction_history = []

        self.create_menu()
        self.show_home_page()

    def create_menu(self):
        self.menubar = tk.Menu(self.root)
        app_menu = tk.Menu(self.menubar, tearoff=0)
        app_menu.add_command(label="User Manual", command=self.show_user_manual)
        app_menu.add_command(label="Toggle Dark Mode", command=self.toggle_dark_mode)
        app_menu.add_command(label="About the App", command=self.show_about_page)
        self.menubar.add_cascade(label="Menu", menu=app_menu)
        self.root.config(menu=self.menubar)

    def clear_window(self):
        for widget in self.root.winfo_children():
            if not isinstance(widget, tk.Menu):
                widget.destroy()

    def apply_theme(self):
        bg = '#1e1e1e' if self.dark_mode else 'white'
        fg = 'white' if self.dark_mode else 'black'
        self.root.configure(bg=bg)
        return bg, fg

    def back_button(self, command):
        tk.Button(self.root, text="\u2190 Back", command=command, bg='lightgrey').place(x=10, y=10)

    def show_home_page(self):
        self.clear_window()
        bg, fg = self.apply_theme()

        left_frame = tk.Frame(self.root, bg=bg)
        left_frame.pack(side='left', fill='both', expand=True)
        right_frame = tk.Frame(self.root, bg=bg)
        right_frame.pack(side='right', fill='both', expand=True)

        tk.Label(left_frame, text="\U0001F3A7 Speech Emotion Recognition", font=('Helvetica bold', 18), bg=bg, fg=fg).pack(pady=40)

        tk.Button(left_frame, text="\U0001F399\ufe0f Record Audio", command=self.record_audio_page, bg='orange').pack(pady=10)
        tk.Button(left_frame, text="\U0001F4C1 Upload Audio", command=self.upload_audio_page, bg='lightgreen').pack(pady=10)
        tk.Button(left_frame, text="\U0001F4DC Prediction History", command=self.show_history_page, bg='lightblue').pack(pady=10)
        tk.Button(left_frame, text="\u274C Exit", command=self.confirm_exit, bg='red', fg='white').pack(pady=10)

        if os.path.exists(self.logo_path):
            logo_image = Image.open(self.logo_path)
            logo_image = logo_image.resize((400, 550), Image.Resampling.LANCZOS)
            logo_tk = ImageTk.PhotoImage(logo_image)
            logo_label = tk.Label(right_frame, image=logo_tk, bg=bg)
            logo_label.image = logo_tk
            logo_label.pack()

    def confirm_exit(self):
        if messagebox.askokcancel("Exit", "Do you really want to exit?"):
            self.root.destroy()

    def toggle_dark_mode(self):
        self.dark_mode = not self.dark_mode
        self.show_home_page()

    def show_user_manual(self):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        manual = (
            "\U0001F4D8 USER MANUAL\n\n"
            "1. \U0001F399\ufe0f Click 'Record Audio' to use your microphone.\n"
            "2. \U0001F4C1 Click 'Upload Audio' to select a .wav file.\n"
            "3. After prediction, you'll see:\n"
            "   - Emotion name\n"
            "   - Emoji animation\n"
            "   - Emotion probability chart\n"
            "4. Check 'Prediction History' for past results.\n"
            "5. Only '.wav' files are supported."
        )
        tk.Label(self.root, text=manual, justify="left", font=('Arial', 12), wraplength=550, bg=bg, fg=fg).pack(padx=20, pady=30)

    def show_about_page(self):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        about = (
            "\u2139\ufe0f ABOUT THE APP\n\n"
            "\U0001F539 FEATURES:\n"
            "- Record or upload audio\n"
            "- Predict emotion from speech\n"
            "- Animated emoji output\n"
            "- Bar chart of prediction confidence\n"
            "- Export results as CSV\n"
            "- Dark mode UI\n\n"
            "\U0001F539 APPLICATIONS:\n"
            "- AI Assistants\n"
            "- Customer Service\n"
            "- Mental Health Monitoring\n"
            "- Learning & Research\n\n"
            "\U0001F539 CREDITS:\n"
            "- Dataset: TESS (University of Toronto)\n"
            "- Developed using Python + Tkinter"
        )
        tk.Label(self.root, text=about, justify="left", font=('Arial', 12), wraplength=550, bg=bg, fg=fg).pack(padx=20, pady=30)

    def show_history_page(self):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        tk.Label(self.root, text="\U0001F4DC Prediction History", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=20)
        if self.prediction_history:
            for i, (file_name, emotion) in enumerate(self.prediction_history[::-1], start=1):
                tk.Label(self.root, text=f"{i}. {file_name} — Emotion: {emotion}", bg=bg, fg=fg).pack(anchor='w', padx=20)
            tk.Button(self.root, text="\U0001F4BE Export as CSV", command=self.export_csv, bg='orange').pack(pady=10)
        else:
            tk.Label(self.root, text="No history yet.", bg=bg, fg=fg).pack()

    def export_csv(self):
        file_path = filedialog.asksaveasfilename(defaultextension=".csv", filetypes=[("CSV files", "*.csv")])
        if file_path:
            with open(file_path, mode='w', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(["File Name", "Predicted Emotion"])
                writer.writerows(self.prediction_history)
            messagebox.showinfo("Success", "History exported successfully!")

    def upload_audio_page(self):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        def choose_file():
            file_path = filedialog.askopenfilename(filetypes=[("WAV Audio", "*.wav")])
            if file_path:
                self.display_result(file_path, os.path.basename(file_path))
        tk.Label(self.root, text="\U0001F4C1 Upload a WAV File", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=40)
        tk.Button(self.root, text="Upload Audio", command=choose_file, bg='orange').pack(pady=10)

    def record_audio_page(self):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        def record_and_predict():
            duration = 4
            fs = 44100
            tk.Label(self.root, text="Recording...", fg="red", bg=bg).pack()
            recording = sd.rec(int(duration * fs), samplerate=fs, channels=1)
            sd.wait()
            with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as temp_file:
                wav.write(temp_file.name, fs, recording)
                self.display_result(temp_file.name, "Recorded_Audio.wav")
        tk.Label(self.root, text="\U0001F399\ufe0f Record Your Voice", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=40)
        tk.Button(self.root, text="Start Recording", command=record_and_predict, bg='orange').pack(pady=10)

    def display_result(self, file_path, file_name):
        self.clear_window()
        self.back_button(self.show_home_page)
        bg, fg = self.apply_theme()
        predicted_emotion, probabilities = predict_emotion(file_path)
        self.prediction_history.append((file_name, predicted_emotion))
        tk.Label(self.root, text="Predicted Emotion:", font=('Helvetica bold', 16), bg=bg, fg=fg).pack(pady=10)
        tk.Label(self.root, text=predicted_emotion, font=('Helvetica bold', 20), fg='blue', bg=bg).pack()
        emoji_path = self.emotion_to_emoji.get(predicted_emotion)
        if emoji_path and os.path.exists(emoji_path):
            self.emoji_image = tk.PhotoImage(file=emoji_path)
            factor = max(1, int(self.emoji_image.width() / 240))
            resized = self.emoji_image.subsample(factor)
            self.emoji_label = tk.Label(self.root, image=resized, bg=bg)
            self.emoji_label.image = resized
            self.emoji_label.pack(pady=10)
        self.show_emotion_bar_chart(probabilities)

    def show_emotion_bar_chart(self, probabilities):
        fig, ax = plt.subplots(figsize=(6, 3), dpi=100)
        emotions = list(probabilities.keys())
        probs = list(probabilities.values())
        ax.bar(emotions, probs, color='skyblue')
        ax.set_title('Emotion Probabilities')
        ax.set_ylim(0, 1)
        ax.set_ylabel('Probability')
        canvas = FigureCanvasTkAgg(fig, master=self.root)
        canvas.draw()
        canvas.get_tk_widget().pack(pady=10)

if __name__ == "__main__":
    root = tk.Tk()
    app = EmotionApp(root)
    root.mainloop()

# %%
pip install transformers torchaudio
# Out:
# Collecting transformers
#   Downloading transformers-4.51.1-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torchaudio in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: filelock in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.14.0)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch==2.2.2 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torchaudio) (2.2.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torch==2.2.2->torchaudio) (4.13.1)
# Requirement already satisfied: sympy in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torch==2.2.2->torchaudio) (1.12)
# Requirement already satisfied: networkx in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torch==2.2.2->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torch==2.2.2->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from torch==2.2.2->torchaudio) (2024.3.1)
# Requirement already satisfied: colorama in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch==2.2.2->torchaudio) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\moham\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch==2.2.2->torchaudio) (1.3.0)
# Downloading transformers-4.51.1-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.4 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/10.4 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/10.4 MB 3.4 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/10.4 MB 3.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.4 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.4 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 7.1/10.4 MB 4.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.4 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 5.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    --------------------- ------------------ 1.3/2.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.30.2 regex-2024.11.6 safetensors-0.5.3 tokenizers-0.21.1 transformers-4.51.1
# Note: you may need to restart the kernel to use updated packages.
